# %% [markdown]
# <a href="https://colab.research.google.com/github/HarukiMurakami04/P.A-27-2-26/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#tipos numericos
idade = 14 #int
altura = 1.75 #float
numero_complexo = 4j+10 #complex

#tipo texto
nome = "Haruki" #str

#tipo booleano
esta_chovendo = True #bool

#tipo lista (mutavel)
numeros = [1,2, 3, 4, 5] #list

#tipo tupla (imutavel)
coordenadas = {10, 20} #tuple

#tipo conjunto (valores unicos)
vogais = {'a', 'e', 'i', 'o', 'u'} #set

#tipo dicionario (chave-valor)
pessoa = {"nome":"Haruki", "idade":14} #dict

# %%
print (f"Nome: {nome}, Idade: {idade}, Altura: {altura}")
# Out:
# Nome: Haruki, Idade: 14, Altura: 1.75
