# %% [markdown]
# <a href="https://colab.research.google.com/github/HarukiMurakami04/P.A-27-2-26/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula de Programação e Algoritímos
#
# * Calcular uma área
#
# # Entrada
#
# Ler lado1
# Ler lado2
#
# #Processamento
#
# area - lado1 + lado2
#
# #Saída
#
# escrever total da área

# %%
#variável que recebe o valor dos lados

#Entrada
lado1 = 7
lado2 = 3

# %%
#Processamento

area = lado1 * lado2

# %%
#Saída

print (f" total da area calculada: {area} metros quadrados")
# Out:
#  total da area calculada: 21 metros quadrados

# %% [markdown]
# Operadores Aritiméticas:
#
#
# 1. Soma = +
# 2. Subtração = -
# 3. Multiplicação = *
# 4. Divisão = /

# %% [markdown]
# Atividade:
#
# Fazer um algoritímo e depois o programa que recebe 4 notas do aluno e calcula a  média aritimética e imprime a média

# %% [markdown]
# Aula de Programação e Algoritímos
#
# * Calcular Nota do Bimestre (Treino)
#
# # Entrada
#
# Ler Nota1
# Ler Nota2
# Ler Nota3
# Ler Nota4
#
# #Processamento
#
# Nota = Nota1 + Nota2 + Nota3 + Nota4
# Notadiv = Nota /4
#
# #Saída
#
# escrever Nota final

# %%
#Varioavel que recebe as notas do aluno

#Entrada
Nota1 = 6
Nota2 = 9
Nota3 = 8
Nota4 = 7

# %%
#Processameto

Nota = Nota1 + Nota2 + Nota3 + Nota4
Notadiv = Nota /4

# %%
#Saída

print(f" Valor do resultado da sua nota bimestral: {Notadiv} Nota final")
# Out:
#  Valor do resultado da sua nota bimestral: 7.5 Nota final

# %% [markdown]
# Aula de Programação e Algoritímos
#
# * Calcular um valor dobrando-o
#
# # Entrada
#
# valor=5
# #Processamento
#
# result = valor *2
#
# #Saída
#
# escrever valor dobrado

# %%
#Entrada
valor = 5

# %%
#processamento

Result = valor *2

# %%
#saida
print(f"valor dobrado:{Result}")
# Out:
# valor dobrado:10
